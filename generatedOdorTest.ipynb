# %%
import odor_stat_calculations as osc
import pandas as pd
import numpy as np

# %%
df = pd.read_hdf('~/An/assets/predicted.h5')

# %%
osc.get_time_col(df,1)

# %%
df
# Out:
#           odor  windx  windy          x          y  scaled_odor  \
# 0     0.000000    0.4    0.0  -1.243577  -3.449493     0.000000
# 1     0.000000    0.4    0.0  -1.491535  -2.041056     0.000000
# 2     0.000000    0.4    0.0  -1.507809  -1.133879     0.000000
# 3     0.000000    0.4    0.0  -1.329522  -0.636089     0.000000
# 4     0.000000    0.4    0.0  -0.993793  -0.455814     0.000000
# ...        ...    ...    ...        ...        ...          ...
# 1045  0.144968    0.4    0.0  18.786324  16.687531     1.503837
# 1046  0.000000    0.4    0.0  18.748664  17.177608     0.000000
# 1047  0.000000    0.4    0.0  18.638074  18.036184     0.000000
# 1048  0.000000    0.4    0.0  18.439033  19.310186     0.000000
# 1049  0.000000    0.4    0.0  18.136020  21.046541     0.000000
#
#       predicted_odor  time
# 0           0.506536     0
# 1           0.086572     1
# 2           0.054878     2
# 3           0.075544     3
# 4           0.135002     4
# ...              ...   ...
# ...
